# %% [markdown]
# # Authors
# Ikram Kohil, 2019115 \
# Johnatan Gao, 2013298

# %% [markdown]
# # Part 1 - CFG Construction

# %% [markdown]
# ## 1.1 Utility functions

# %%
import os
from pathlib import Path
from code_analysis import ASTReader
from code_analysis import ASTException, CFG, AST

# Global variable - directory where cfg.json and .dot files generated by our code will be stored 
part1_output_directory = "output/part_1/"
part2_output_directory = "output/part_2/"
ast_reader = ASTReader()

# Utility functions taken from TP1
def get_json_files(extension, directory):
   directory = Path(directory)
   return [str(file) for file in directory.rglob(extension)]

def create_output_file(filename, directory):
    # Check if output directory exists, if not, create it
    if not os.path.exists(directory):
        os.makedirs(directory)

    # Check if output file already exists, if so, delete and create new file
    if os.path.exists(filename):
        os.remove(filename)

    # Open in "append" mode to avoid overwriting the whole file after each modification
    return open(directory + filename, "a")

def close_output_file(file):
   file.close()

def get_filename_from_path(full_filepath):
    # Splits string into array of 2 elements, the last one corresponding to the segment we want
    segments = full_filepath.rsplit("/", 1)
    fullname = full_filepath

    # Error handling, in case file in question is not in a folder
    if len(segments) > 1:
        fullname = segments[1]

    return fullname.rsplit('.')[0]

# %% [markdown]
# # 1.2 Create visitor

# %% [markdown]
# ## 1.2.1 Function call
# <div style="text-align: justify;">
#
# For this section, we simply followed the provided example to generate the relevant nodes in the `visit_FUNCTION_CALL` method. A private function `__update_context()` was created to easily update a cloned context after the creation of a new node. A modification had to be done in the `visit_GENERIC` function in order to automatically create an argument node after an argument is visited in the AST. Further details are provided in the comments of each function.
#
# </div>

# %% [markdown]
# ## 1.2.2 IfThenElse Statement
# <div style="text-align: justify;">
#
# For this section, no particular difficulty was encountered, but a modification had to be done to the provided `visit_BinOP` function in order to draw the appropriate relationship arrows upon visit to avoid having to manually do then in the `visit_IF_THEN_ELSE` method. It is important to note that we operated under the assumption that in the ast, the right child (excluding the condition child) of an `IfThen/Else` statement is always the statement executed when the condition is true, and the left when false.
#
# Two additionnal private functions were also created: `___visit_CONDITION` and `__visit_STATEMENT_BODY` to minimize code duplication.
#
# </div>

# %% [markdown]
# ## 1.2.3 While
# <div style="text-align: justify;">
#
# Visited using the `visit_WHILE` method. Given that were also created: `___visit_CONDITION` and `__visit_STATEMENT_BODY` were created previously, this function was quite straight forward.
#
# </div>

# %% [markdown]
# ## 1.2.4 While/Continue Break
# <div style="text-align: justify;">
#
# Given the way our previous functions were structured as well as the fact that there is no specific tag for a while/continue/break, no particular function was made for this case. Instead, the handling of continue/break nodes is done in `___visit_GENERIC`. Since a break/continue can only be called inside a `StatementBody`, and that our `__visit_STATEMENT_BODY` simply calls the `visit_node` function, the logic for break/continue had to be done in `___visit_GENERIC`.
#
# In the case of a break, the while is immediately ended, and thus we needed the id of the `WhileEnd` node. To do so, we went back up the AST until the id of the `While` node was retrieved. From there, we retrieved the id of the `Condition` node. From the AST id of the `Condition` node, we retrieved its CFG id, and then retrieved the id of the `WhileEnd` node (all of which could have been done from the cfg but judged that it was much easier and less likely to fail if done from the AST).
#
# In the case of a continue, the current iteration is interrupted and the while restarted, and thus we needed the id of the `While` node. Therefore, we went back up the AST until the id of the `While` node was retrieved, and retrieved its CFG id.
#
# The context had to be updated accordingly after each case, by setting `ctx["endId"] = 0` to ignore the code following these statements (to avoid drawing unnecessary edges).
#
# </div>

# %%
# Part of this code was provided by the teaching assisstant.

class ASTtoCFGVisitor:
    def __init__(self):
        self.ast = None
        self.cfg = CFG()
        self.iNextNode = 0

    def get_new_node(self) -> int:
        self.iNextNode += 1
        return self.iNextNode

    def visit(self, ast: AST):
        self.ast = ast
        self.cfg = CFG()
        print(f"Visit AST from file {self.ast.get_filename()}")
        self.visit_ROOT()
        return self.cfg

    def visit_ROOT(self):
        ctx = {}
        entryNodeId = self.get_new_node()
        stopNodeId = self.get_new_node()
        rootAST = self.ast.get_root()
        self.cfg.set_root(entryNodeId)

        self.cfg.set_type(entryNodeId, "Entry")
        self.cfg.set_image(entryNodeId, "main")
        self.cfg.set_type(stopNodeId, "Exit")

        ctx['parent'] = entryNodeId
        ctx['scope'] = entryNodeId
        ctx['stopId'] = stopNodeId

        if self.ast.get_type(rootAST) == "Start":
            self.cfg.set_node_ptr(rootAST, entryNodeId)

        self.visit_node(rootAST, ctx)
        self.cfg.add_edge(ctx['endId'], stopNodeId)

    # chain nodes
    def visit_GENERIC(self, ast_node_id: int, ctx: dict) -> int:       
        cfg_node = self.get_new_node()
        self.cfg.set_node_ptr(ast_node_id, cfg_node)
        self.cfg.set_type(cfg_node, self.ast.get_type(ast_node_id))
        self.cfg.set_image(cfg_node, self.ast.get_image(ast_node_id))
        self.cfg.add_edge(ctx["parent"], cfg_node)
        

        # Break handling
        if self.cfg.get_type(cfg_node) == "Break":
            # If break statement, go back up the ast to find the while node again 
            # Once while node found, retrieve the whileEnd node from the cfg and point to it, since a break statement will exit the loop and skip all following code within the loop
            parent = self.ast.get_parents(ast_node_id)[0]
            while not self.ast.get_type(parent) == "While":
                parent = self.ast.get_parents(parent)[0]
            
            while_children = self.ast.get_children(parent)
            ast_condition_node = [child_id for child_id in while_children if self.ast.get_type(child_id) == "Condition"][0]
            cfg_condition_node = self.cfg.get_node_cfg_ptr(ast_condition_node)
            condition_children = self.cfg.get_children(cfg_condition_node)
            while_end_node = [child_id for child_id in condition_children if self.cfg.get_type(child_id) == "WhileEnd"][0]
            self.cfg.add_edge(cfg_node, while_end_node)

            # Reset end id since no code after the break will be executed
            ctx["endId"] = 0
            return cfg_node
        
        # Continue handling
        if self.cfg.get_type(cfg_node) == "Continue":
            # If continue statement, find the while node again and point to it, since the continue statement will skip all following code and restart the loop
            parent = self.ast.get_parents(ast_node_id)[0]
            while not self.ast.get_type(parent) == "While":
                parent = self.ast.get_parents(parent)[0]
            
            cfg_while_node = self.cfg.get_node_cfg_ptr(parent)
            self.cfg.add_edge(cfg_node, cfg_while_node)

            # Reset end id since no code after the continue will be executed
            ctx["endId"] = 0
            return cfg_node

        ctx["endId"] = cfg_node

        # In the case of an argument being called, add the argument node at the end of the call
        # Verify that the parent of the current node is an ArgumentList
        # Also verify that the current node isnt an argument itself, to account for the different parser used in the while_continue_break
        if self.ast.get_type(self.ast.get_parents(ast_node_id)[0]) == "ArgumentList" and not self.cfg.get_type(cfg_node) == "Argument":
            # Create argument node and update ctx accordingly
            cfg_argument_node = self.get_new_node()
            self.cfg.set_type(cfg_argument_node, "Argument")
            self.cfg.add_edge(ctx['endId'], cfg_argument_node)
            self.__update_context(ctx['endId'], cfg_argument_node, ctx)

        new_ctx = dict(ctx) # clone ctx
        new_ctx["parent"] = cfg_node
        for child_id in self.ast.get_children(ast_node_id):
            self.visit_node(child_id, new_ctx)
            new_ctx["parent"] = new_ctx["endId"]

        ctx["endId"] = new_ctx["endId"]
        return cfg_node

    def visit_GENERIC_BLOCK(self, ast_node_id: int, ctx: dict):
        new_ctx = dict(ctx) # clone ctx
        for child_id in self.ast.get_children(ast_node_id):      
            self.visit_node(child_id, new_ctx)
            new_ctx["parent"] = new_ctx["endId"]
        ctx["endId"] = new_ctx["endId"]

        return None

    def visit_BINOP(self, ast_node_id: int, ctx: dict) -> int:
        #Create BinOP node
        cfg_node = self.get_new_node()
        self.cfg.set_node_ptr(ast_node_id, cfg_node)
        self.cfg.set_type(cfg_node, self.ast.get_type(ast_node_id))
        self.cfg.set_image(cfg_node, self.ast.get_image(ast_node_id))

        #Visit right child
        new_ctx = dict(ctx) # clone ctx
        self.visit_node(self.ast.get_children(ast_node_id)[1], new_ctx)
        right = new_ctx['endId']

        #Visit right left
        new_ctx = dict(ctx) # clone ctx
        new_ctx["parent"] = right
        self.visit_node(self.ast.get_children(ast_node_id)[0], new_ctx)
        left = new_ctx['endId']

        #Link left child with BinOp
        self.cfg.add_edge(left, cfg_node)

        ## Added  section to draw the appropriate relationship arrows for each type of of binary operator
        ## If parent is also binOP, then its an operation (ie x = 1 + 1) and the call arg function needs to be called instead
        cfg_node_type = self.cfg.get_type(cfg_node)
        node_parent = self.ast.get_parents(ast_node_id)

        if cfg_node_type == "BinOP":
            if node_parent and not self.ast.get_type(node_parent[0]) == "BinOP":
                self.cfg.set_op_hands(cfg_node, left, right)
            elif node_parent and self.ast.get_type(node_parent[0]) == "BinOP":
                self.cfg.add_call_arg(cfg_node, left)
                self.cfg.add_call_arg(cfg_node, right)
        elif cfg_node_type == "RelOP":
            self.cfg.add_call_arg(cfg_node, left)
            self.cfg.add_call_arg(cfg_node, right)


        ctx["endId"] = cfg_node
        return cfg_node
    
    def visit_FUNCTION_CALL(self, ast_node_id: int, ctx: dict) -> int:
        # Get function node
        cfg_node = self.visit_GENERIC(ast_node_id, ctx)
        self.cfg.set_node_ptr(ast_node_id, cfg_node)
        
        # Get function id (its name) 
        children = self.cfg.get_children(cfg_node)
        cfg_function_id = [child_id for child_id in children if self.cfg.get_type(child_id) == "Id"][0]
        
        # Create node representing the call to the function and link it to last cfg node
        cfg_begin_node = self.get_new_node()
        self.cfg.set_type(cfg_begin_node, "CallBegin")
        self.cfg.set_image(cfg_begin_node, self.cfg.get_image(cfg_node))
        self.cfg.add_edge(ctx["endId"], cfg_begin_node)
        
        # We created a new node; Clone and update context
        new_ctx = dict(ctx) # clone ctx
        self.__update_context(ctx["endId"], cfg_begin_node, new_ctx)

        # Set calls to the function
        self.cfg.set_call_expr(cfg_begin_node, cfg_function_id)

        # Set call to arguments
        # Current ast node is functioncall, so get argumentlist child from ast
        ast_children = self.ast.get_children(ast_node_id)
        argument_list = [child_id for child_id in ast_children if self.ast.get_type(child_id) == "ArgumentList"]

        if len(argument_list) > 0:
            arguments = self.ast.get_children(argument_list[0])

            for argument in arguments:
                cfg_argument_node = self.cfg.get_node_cfg_ptr(argument)
                self.cfg.add_call_arg(cfg_begin_node, cfg_argument_node)
        
        # Create node representing the end of the call to the function
        cfg_end_node = self.get_new_node()
        self.cfg.set_type(cfg_end_node, "CallEnd")
        self.cfg.set_image(cfg_end_node, self.cfg.get_image(cfg_node))
        self.cfg.set_call(cfg_begin_node, cfg_end_node)
        self.__update_context(cfg_begin_node, cfg_end_node, new_ctx)

        # Create node representing the return value
        cfg_ret_value_node = self.get_new_node()
        self.cfg.set_type(cfg_ret_value_node, "RetValue")
        self.cfg.add_edge(cfg_end_node, cfg_ret_value_node)
        self.__update_context(cfg_end_node, cfg_ret_value_node, new_ctx)

        # Update the original context's last node id (endId)
        ctx["endId"] = new_ctx["endId"]
        return cfg_node

    def visit_IF_THEN_ELSE(self, ast_node_id: int, ctx: dict) -> int:
        # Get IfThen/Else node
        cfg_if_node = self.get_new_node()
        self.cfg.set_node_ptr(ast_node_id, cfg_if_node)

        # Generate If node first and link it to parent
        self.cfg.set_type(cfg_if_node, "If")
        self.cfg.set_image(cfg_if_node, self.ast.get_image(ast_node_id))
        self.cfg.add_edge(ctx["parent"], cfg_if_node)

        # Get children from ast to retrieve the condition node
        children = self.ast.get_children(ast_node_id)
        ast_condition_node = [child_id for child_id in children if self.ast.get_type(child_id) == "Condition"][0]
        
        # Create and visit condition node
        new_ctx = dict(ctx) # clone ctx
        cfg_condition_node = self.__visit_CONDITION(cfg_if_node, ast_condition_node, new_ctx)

        # Retrieve statement bodies (what gets executed if true/false)
        ast_statement_nodes = [child_id for child_id in children if self.ast.get_type(child_id) == "StatementBody"]

        # Create end of statement node in advance
        cfg_if_end_node = self.get_new_node()
        self.cfg.set_type(cfg_if_end_node, "IfEnd")

        true_stmt_ctx = dict(new_ctx) # clone modified ctx and set the condition node as parent
        # Visit right child (true statement body node)
        if len(ast_statement_nodes) > 0:
            cfg_true_statement_body_node = self.__visit_STATEMENT_BODY(cfg_condition_node, ast_statement_nodes[0], true_stmt_ctx)
            self.cfg.add_edge(cfg_true_statement_body_node, cfg_if_end_node)

        false_stmt_ctx = dict(new_ctx) # clone modified ctx and set the condition node as parent
        # Visit left child (else statement body node)
        if len(ast_statement_nodes) > 1:
            cfg_false_statement_body_node = self.__visit_STATEMENT_BODY(cfg_condition_node, ast_statement_nodes[1], false_stmt_ctx)
            self.cfg.add_edge(cfg_false_statement_body_node, cfg_if_end_node)
        else:
            # If no else statement, link end node to last visited node
            self.cfg.add_edge(new_ctx["endId"], cfg_if_end_node)    
        
        self.__update_context(new_ctx["endId"], cfg_if_end_node, new_ctx)
        ctx["endId"] = new_ctx["endId"]

        return cfg_if_node
    
    def visit_WHILE(self, ast_node_id: int, ctx: dict):
        # Get while node
        cfg_node = self.get_new_node()
        self.cfg.set_node_ptr(ast_node_id, cfg_node)

        # Generate while node and link it to parent
        self.cfg.set_type(cfg_node, self.ast.get_type(ast_node_id))
        self.cfg.set_image(cfg_node, self.ast.get_image(ast_node_id))
        self.cfg.add_edge(ctx["parent"], cfg_node)

        # Get children from ast to retrieve the condition node
        children = self.ast.get_children(ast_node_id)
        ast_condition_node = [child_id for child_id in children if self.ast.get_type(child_id) == "Condition"][0]
        
        # Create and visit condition node
        new_ctx = dict(ctx) # clone ctx
        cfg_condition_node = self.__visit_CONDITION(cfg_node, ast_condition_node, new_ctx)

        # Create node referring to end of while and update context accordingly
        cfg_while_end_node = self.get_new_node()
        self.cfg.set_type(cfg_while_end_node, "WhileEnd")
        self.__update_context(cfg_condition_node, cfg_while_end_node, new_ctx)
        self.cfg.add_edge(new_ctx["parent"], cfg_while_end_node)

        # Visit right child (true statement body node, which will be executed if the condition is true)
        ast_statement_nodes = [child_id for child_id in children if self.ast.get_type(child_id) == "StatementBody"]
        true_stmt_ctx = dict(new_ctx) # clone modified ctx and set the condition node as parent
        cfg_statement_body_node = self.__visit_STATEMENT_BODY(cfg_condition_node, ast_statement_nodes[0], true_stmt_ctx)
        self.cfg.add_edge(cfg_statement_body_node, cfg_node)

        ctx["endId"] = new_ctx["endId"]
        return cfg_node

    def __visit_CONDITION(self, cfg_parent_node, ast_condition_node, condition_ctx):
        cfg_condition_node = self.get_new_node()
        self.cfg.set_node_ptr(ast_condition_node, cfg_condition_node)
        self.cfg.set_type(cfg_condition_node, self.ast.get_type(ast_condition_node))

        # Visit child
        # Update context to the condition's parent
        condition_ctx['parent'] = cfg_parent_node
        condition_first_child = self.ast.get_children(ast_condition_node)[0]
        
        self.visit_node(condition_first_child, condition_ctx)
        condition_content = condition_ctx['endId']

        # Link bottom child of the condition content with condition node and update context to point to condition as last node for now
        self.cfg.add_edge(condition_content, cfg_condition_node)
        self.__update_context(condition_content, cfg_condition_node, condition_ctx)
    
        # Return last visited cfg node
        return cfg_condition_node
    
    def __visit_STATEMENT_BODY(self, cfg_parent_node, ast_stmt_node, stmt_ctx):
        stmt_ctx['parent'] = cfg_parent_node
        new_ctx = dict(stmt_ctx)

        # Ignore StatementBody node and visit its child directly
        statement_body_child = self.ast.get_children(ast_stmt_node)[0]
        self.visit_node(statement_body_child, new_ctx)

        # Return last visited cfg node
        return new_ctx['endId']

    def __update_context(self, parent_node_id, current_node_id, ctx_to_update):
        ctx_to_update["parent"] = parent_node_id
        ctx_to_update["endId"] = current_node_id


    def visit_node(self, ast_node_id: int, ctx: dict):
        cur_type = self.ast.get_type(ast_node_id)
        if cur_type is None:
            raise ASTException("Missing type in a node")

        if cur_type in ["BinOP", "RelOP", "LogicOP"]:
            self.visit_BINOP(ast_node_id, ctx)
        elif cur_type in ["Block", "Start"]:
            self.visit_GENERIC_BLOCK(ast_node_id, ctx)
        elif cur_type in ["FunctionCall"]:
            self.visit_FUNCTION_CALL(ast_node_id, ctx)
        elif cur_type in ["IfThenElseStatement", "IfThenStatement"]:
            self.visit_IF_THEN_ELSE(ast_node_id, ctx)
        elif cur_type in ["While"]:
            self.visit_WHILE(ast_node_id, ctx)
        elif cur_type in ["PLACEHOLDER"]: # Node to ignore
            self.visit_passthrough(ast_node_id, ctx)
        else:
            self.visit_GENERIC(ast_node_id, ctx)

    def visit_passthrough(self, ast_node_id: int, ctx: dict):
        for child_id in self.ast.get_children(ast_node_id):
            self.visit_node(child_id, ctx)

# %% [markdown]
# ## 1.3 For each AST file, load AST in memory and visit it to generate a CFG

# %%
def generate_CFG_for_AST_in_folder(directory):
    # Retrieve filenames of all ast in the specified directory
    astFilenames = get_json_files('*.ast.json', directory)

    # Iterate over the filenames array
    for filename in astFilenames:
        # Load ast in memory
        ast = ast_reader.read_ast(filename)

        # Prepare cfg.json file
        output_file = create_output_file(get_filename_from_path(filename) + ".php.cfg.json", part1_output_directory)

        # Visit currently loaded ast
        visitor = ASTtoCFGVisitor()
        cfg = visitor.visit(ast)
        output_file.write(cfg.to_json())
        close_output_file(output_file)

        # Generate and show graph
        cfg.show(filename=part1_output_directory + get_filename_from_path(filename) + ".php.cfg.dot")

# %% [markdown]
# ## 1.4 Specify directory to analyze

# %%
directory_to_analyze = "../part_1/"
generate_CFG_for_AST_in_folder(directory_to_analyze)
# Out:
# Visit AST from file code.php
# Visit AST from file code.php
# Visit AST from file code.php
# Visit AST from file code.php
# Visit AST from file code.php
# Visit AST from file code.php
# Visit AST from file code.php
# Visit AST from file code.php

# %% [markdown]
# # Part 2 - Dead Code Detection
# <div style="text-align: justify;">
#
# The results of this search will be stored in the `output/part_2/dead_code_results.txt` file.
#
# </div>

# %% [markdown]
# ## 2.1 Create visitor
# <div style="text-align: justify;">
#
# The `CFGFunctionVisitor` starts visiting a CFG from its main entry node and visits every child until the bottom of the tree. This ensures that only the "active" (executed) code is visited, and leaves out the dead nodes, since they are do not have an entry node in their ancestry. This is kept in the `dead_nodes` global dictionnary, where the key is the filename and the value is an array containing the node ids of the dead code.
#
# As for the interprocedural dead code, while visiting the main code (starting from main entry node) of each file, we add all the names of the functions called to `function_calls`. This set is updated with each function called in each file. As for the function definitions, they are also visited using the `self.cfg.get_func_entry_nodes()` function. They are store in the `function_definitions` dictionnary, where the filename is the key, and the value is a set containig the names of the functions defined in the class. The filtering of the interprocedural dead code is then done in section 2.2.
#
# Further details are provided in the comments of the code.
#
# </div>

# %%
from code_analysis import CFGReader
import sys

dead_nodes = {}
function_definitions = {}
function_calls = set() # Doesnt need to be a dictionnary since we will keep track of all function calls across the whole directory without distinction

# Create a visitor that keeps track of all function statements and function calls
class CFGFunctionVisitor:
    def __init__(self, filename):
        self.cfg = None
        self.filename = filename

        # Stored in array
        self.visited_nodes = set() # Using a set to avoid adding nodes that have already been visited
        self.function_calls_names = set()
        self.defined_func_names = set()
        self.intraprocedural_dead_nodes = []

    def visit(self, cfg: CFG):
        self.cfg = cfg
        print(f"Visiting CFG from file {self.filename}")

        # First, start from entry node to visit what the program itself executes
        # By starting the visit from the root (entry node), and visiting every child
        # We make sure to not visit dead nodes, since those do not have an entry node in their ancestry (same logic when visiting functions)
        self.__visit(self.cfg.get_root())

        # Then visit the functions that have been defined, if any
        # Start from entry node of function
        defined_func_entry_nodes = self.cfg.get_func_entry_nodes()

        # These two steps ensure we visit active nodes of all procedures
        if len(defined_func_entry_nodes) > 0:
            for entry_node in defined_func_entry_nodes:
                self.defined_func_names.add(self.cfg.get_entry_func_name(entry_node))

                # Set called_fn_flag to false to skip the functioncall search while visiting a function definition
                self.__visit(entry_node, called_fn_flag=False)

        # Once all nodes visited, filter the visited nodes from all cfg nodes
        # This will filter out intraprocedural dead code
        cfg_nodes = self.cfg.get_node_ids()
        self.intraprocedural_dead_nodes = [node_id for node_id in cfg_nodes if node_id not in self.visited_nodes]

        # Store everything in dictionnaries/array to process later
        function_calls.update(self.function_calls_names)
        dead_nodes.update({self.filename: self.intraprocedural_dead_nodes})
        function_definitions.update({self.filename:  self.defined_func_names})

    def __visit(self, node_id: int, called_fn_flag = True):
        self.visited_nodes.add(node_id)

        # The called_fn_flag helps with filtering the dead functions
        # Set to true while visiting main code, false when visiting function definition
        if called_fn_flag:
            # Retrieve the functions that were called
            if self.cfg.get_type(node_id) == "FunctionCall":
                self.function_calls_names.add(self.cfg.get_image(node_id))

        children = self.cfg.get_any_children(node_id)
        for child_id in children:
            # Only visit if not previously visited, for performance
            if child_id not in self.visited_nodes:
                self.__visit(child_id)

# %% [markdown]
# ## 2.2 For each CFG file, load CFG in memory and visit it.
# <div style="text-align: justify;">
#
# In `find_dead_code_from_cfg_in_directory`, each cfg file is visited once to detect all intraprocedural dead code in each file, and to keep track of ALL function definitions and function calls. Then, once all code is visited, we iterate over the array of files (not over the files themselves) to remove all the called functions from the defined functions set. This will ensure that only the functions that were never called remain, which gives us the interprocedural dead code.
#
# </div>

# %%
# Prepare output file and reader
cfg_reader = CFGReader()
dead_code_output_file = create_output_file("dead_code_results.txt", part2_output_directory)

def find_dead_code_from_cfg_in_directory(directory):
    # Retrieve filenames of all cfg in the specified directory
    cfgFilenames = get_json_files('*.cfg.json', directory)

    dead_code_output_file.write(f"________________________ Directory: {directory} ________________________\n")

    # Iterate over the filenames array once to visit all cfgs
    for filename in cfgFilenames:
        # Load cfg in memory
        cfg = cfg_reader.read_cfg(filename)

        # Visit currently loaded cfg
        visitor = CFGFunctionVisitor(filename)
        visitor.visit(cfg)

        # Generate fand show graph; commented because some graphs are far too large and greatly reduced performance
        # cg.show(filename=part2_output_directory + get_filename_from_path(filename) + ".cfg.dot")
    
    # Once all files have been visited, for each file, filter out the called functions from the defined functions
    for filename in cfgFilenames:
        if filename in function_definitions.keys() and filename in dead_nodes.keys():
            # Remove all called functions from the set of defined functions; only the uncalled function names will remain
            function_definitions[filename] -= function_calls

            # Output results
            dead_code_output_file.write(f"------------------------ File: {filename} ------------------------\n")
            dead_code_output_file.write(f"Intraprocedural dead code (node ids): {dead_nodes[filename] or 'None'}\n")
            dead_code_output_file.write(f"Interprocedural dead code (fn names): {function_definitions[filename] or 'None'}\n\n")

# %% [markdown]
# ## 2.3 Specify directory to analyze
# <div style="text-align: justify;">
# Important note: we had to increase the default recursion limit in python, since some files in the wordpress folder were too large and some nodes had more children than the default recursion limit allowed to visit.
# </div>

# %%
sys.setrecursionlimit(10000)
directories_to_analyze = ["../part_2/code_mort/", "../part_2/wordpress/wordpress_ast_cfg/"]

for directory in directories_to_analyze:
    find_dead_code_from_cfg_in_directory(directory)
close_output_file(dead_code_output_file)
# Out:
# Visiting CFG from file ../part_2/code_mort/example2.php.cfg.json
# Visiting CFG from file ../part_2/code_mort/example3.php.cfg.json
# Visiting CFG from file ../part_2/code_mort/example1.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-login.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-signup.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-cron.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-blog-header.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-settings.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-links-opml.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/readme.html.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/license.txt.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-trackback.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/xmlrpc.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-load.php.cfg.json
# (eog:17978): EOG-CRITICAL **: 00:02:44.646: eog_image_get_file: assertion 'EOG_IS_IMAGE (img)' failed
#
# (eog:17978): GLib-GIO-CRITICAL **: 00:02:44.646: g_file_equal: assertion 'G_IS_FILE (file1)' failed
#
# (eog:17978): EOG-CRITICAL **: 00:02:44.646: eog_image_get_file: assertion 'EOG_IS_IMAGE (img)' failed
#
# (eog:17978): GLib-GIO-CRITICAL **: 00:02:44.646: g_file_equal: assertion 'G_IS_FILE (file1)' failed
#
# (eog:17978): EOG-CRITICAL **: 00:02:44.646: eog_image_get_file: assertion 'EOG_IS_IMAGE (img)' failed
#
# (eog:17978): GLib-GIO-CRITICAL **: 00:02:44.646: g_file_equal: assertion 'G_IS_FILE (file1)' failed
#
# (eog:17978): EOG-CRITICAL **: 00:02:44.646: eog_image_get_file: assertion 'EOG_IS_IMAGE (img)' failed
#
# (eog:17978): GLib-GIO-CRITICAL **: 00:02:44.646: g_file_equal: assertion 'G_IS_FILE (file1)' failed
#
# (eog:17978): EOG-CRITICAL **: 00:02:44.646: eog_image_get_file: assertion 'EOG_IS_IMAGE (img)' failed
#
# (eog:17978): GLib-GIO-CRITICAL **: 00:02:44.646: g_file_equal: assertion 'G_IS_FILE (file1)' failed
#
# (eog:17978): EOG-CRITICAL **: 00:02:44.646: eog_image_get_file: assertion 'EOG_IS_IMAGE (img)' failed
#
# (eog:17978): GLib-GIO-CRITICAL **: 00:02:44.646: g_file_equal: assertion 'G_IS_FILE (file1)' failed
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-config-sample.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-activate.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-mail.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/index.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-comments-post.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-metadata-lazyloader.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-feed.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-post-type.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/query.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-user-meta-session-tokens.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/registration.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/feed-rdf.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/functions.wp-styles.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/update.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-oembed-controller.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-customize-section.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/feed-rss2.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/locale.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-locale-switcher.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-comment.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/post-formats.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/default-constants.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-embed.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/cache.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-error.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/post-template.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-user-query.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-simplepie-sanitize-kses.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/template-loader.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-network-query.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-http-streams.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/wp-diff.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-snoopy.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/default-widgets.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/author-template.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/feed-atom.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-customize-control.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-walker-comment.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class.wp-scripts.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-http-encoding.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-term-query.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-simplepie.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/ms-default-filters.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-customize-widgets.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-http-requests-response.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-walker-page-dropdown.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-matchesmapregex.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-http-ixr-client.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/date.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-taxonomy.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/template.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-walker-page.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/user.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/vars.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/wlwmanifest.xml.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/taxonomy.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/comment-template.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class.wp-styles.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-simplepie-file.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/embed.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-image-editor-gd.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/deprecated.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-site.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-dependency.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-user.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/feed-rss.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-term.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/feed-atom-comments.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/ms-functions.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/category.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-walker.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/ms-default-constants.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/option.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/plugin.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/general-template.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-rewrite.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/wp-db.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-locale.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-customize-manager.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-network.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-admin-bar.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/post-thumbnail-template.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-comment-query.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/kses.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/session.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-http-cookie.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-walker-category.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/l10n.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-theme.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-text-diff-renderer-table.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/script-loader.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class.wp-dependencies.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-oembed.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-http-response.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/bookmark.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/registration-functions.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-phpass.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/rss-functions.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-http-requests-hooks.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-image-editor-imagick.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-IXR.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/shortcodes.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/load.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/ms-files.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-walker-nav-menu.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/feed.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-walker-category-dropdown.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/widgets.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-customize-panel.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/meta.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-ajax-response.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-list-util.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/embed-template.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-widget.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/default-filters.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/functions.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-post.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-http-curl.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/version.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-text-diff-renderer-inline.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-role.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-http.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-feed-cache.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-smtp.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/revision.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/nav-menu.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-editor.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/bookmark-template.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/http.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-feed-cache-transient.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/category-template.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-site-query.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-widget-factory.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-roles.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-wp-http-proxy.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/feed-rss2-comments.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/theme.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/class-phpmailer.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/functions.wp-scripts.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/atomlib.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/heartbeat.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/autosave.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/comment-reply.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/customize-views.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wplink.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-embed.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/media-audiovideo.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/colorpicker.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/mce-view.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wplink.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/zxcvbn-async.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/hoverIntent.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/media-grid.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/zxcvbn-async.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/masonry.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/autosave.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/quicktags.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/media-models.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/underscore.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/shortcode.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-embed.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/customize-views.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-embed-template.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-emoji.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-list-revisions.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-backbone.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/twemoji.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-backbone.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/twemoji.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/mce-view.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/customize-preview.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-lists.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/media-views.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/media-editor.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/admin-bar.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/json2.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/heartbeat.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/customize-preview-nav-menus.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wpdialog.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/zxcvbn.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/media-grid.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/json2.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/hoverIntent.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/customize-base.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/customize-loader.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/backbone.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-api.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-emoji-release.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/utils.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/shortcode.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/customize-preview-widgets.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-util.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-pointer.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-emoji-loader.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/customize-preview.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/swfobject.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/customize-models.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/customize-models.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/customize-base.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-embed-template.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/customize-selective-refresh.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/customize-selective-refresh.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/imagesloaded.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-list-revisions.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/comment-reply.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/media-views.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/admin-bar.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-util.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tw-sack.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/media-models.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/media-editor.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wpdialog.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-a11y.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/media-audiovideo.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-emoji.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-auth-check.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/customize-preview-nav-menus.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-a11y.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-emoji-loader.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/customize-preview-widgets.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-ajax-response.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tw-sack.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-api.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-auth-check.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/customize-loader.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/utils.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-custom-header.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/quicktags.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-custom-header.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-ajax-response.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-pointer.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/colorpicker.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/wp-lists.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jcrop/jquery.Jcrop.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jcrop/jquery.Jcrop.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/suggest.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/jquery.schedule.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/jquery.serialize-object.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/jquery.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/jquery.form.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/jquery.form.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/jquery.hotkeys.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/jquery.query.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/suggest.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/jquery-migrate.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/jquery.table-hotkeys.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/jquery.color.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/jquery.table-hotkeys.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/jquery.hotkeys.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/jquery-migrate.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/jquery.masonry.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/jquery.ui.touch-punch.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/effect-transfer.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/effect-scale.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/effect-clip.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/sortable.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/draggable.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/slider.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/autocomplete.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/effect-drop.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/resizable.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/widget.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/menu.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/datepicker.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/dialog.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/selectable.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/core.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/accordion.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/mouse.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/progressbar.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/effect-shake.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/effect-explode.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/effect-blind.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/effect-fade.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/selectmenu.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/effect-bounce.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/effect-fold.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/droppable.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/effect.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/button.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/effect-pulsate.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/effect-highlight.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/position.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/tabs.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/effect-slide.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/tooltip.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/spinner.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/effect-puff.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/jquery/ui/effect-size.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/crop/cropper.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/crop/cropper.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/mediaelement/wp-mediaelement.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/mediaelement/mediaelementplayer.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/mediaelement/wp-playlist.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/mediaelement/wp-mediaelement.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/mediaelement/mediaelement-and-player.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/mediaelement/wp-mediaelement.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/mediaelement/wp-playlist.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/mediaelement/froogaloop.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/mediaelement/wp-mediaelement.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/imgareaselect/jquery.imgareaselect.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/imgareaselect/imgareaselect.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/imgareaselect/jquery.imgareaselect.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/wp-tinymce.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/tiny_mce_popup.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/license.txt.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/langs/wp-langs-en.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/skins/wordpress/wp-content.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/skins/lightgray/content.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/skins/lightgray/skin.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/skins/lightgray/content.inline.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/wpeditimage/plugin.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/wpeditimage/plugin.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/wpemoji/plugin.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/wpemoji/plugin.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/charmap/plugin.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/charmap/plugin.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/lists/plugin.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/lists/plugin.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/wordpress/plugin.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/wordpress/plugin.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/wpview/plugin.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/wpview/plugin.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/wptextpattern/plugin.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/wptextpattern/plugin.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/fullscreen/plugin.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/fullscreen/plugin.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/colorpicker/plugin.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/colorpicker/plugin.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/hr/plugin.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/hr/plugin.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/textcolor/plugin.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/textcolor/plugin.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/wplink/plugin.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/wplink/plugin.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/wpautoresize/plugin.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/wpautoresize/plugin.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/wpgallery/plugin.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/wpgallery/plugin.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/paste/plugin.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/paste/plugin.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/compat3x/plugin.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/compat3x/plugin.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/compat3x/css/dialog.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/media/plugin.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/media/plugin.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/directionality/plugin.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/directionality/plugin.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/wpdialogs/plugin.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/wpdialogs/plugin.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/image/plugin.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/image/plugin.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/tabfocus/plugin.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/plugins/tabfocus/plugin.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/utils/editable_selects.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/utils/mctabs.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/utils/form_utils.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/utils/validate.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/themes/inlite/theme.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/themes/inlite/theme.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/themes/modern/theme.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/tinymce/themes/modern/theme.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/thickbox/thickbox.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/thickbox/thickbox.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/plupload/handlers.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/plupload/handlers.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/plupload/plupload.full.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/plupload/license.txt.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/plupload/wp-plupload.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/plupload/wp-plupload.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/swfupload/handlers.min.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/swfupload/handlers.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/swfupload/swfupload.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/swfupload/license.txt.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/swfupload/plugins/swfupload.swfobject.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/swfupload/plugins/swfupload.speed.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/swfupload/plugins/swfupload.queue.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/js/swfupload/plugins/swfupload.cookies.js.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/widgets/class-wp-nav-menu-widget.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/widgets/class-wp-widget-archives.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/widgets/class-wp-widget-tag-cloud.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/widgets/class-wp-widget-links.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/widgets/class-wp-widget-text.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/widgets/class-wp-widget-media-audio.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/widgets/class-wp-widget-media-image.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/widgets/class-wp-widget-rss.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/widgets/class-wp-widget-search.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/widgets/class-wp-widget-calendar.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/widgets/class-wp-widget-pages.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/widgets/class-wp-widget-media-video.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/widgets/class-wp-widget-categories.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/widgets/class-wp-widget-recent-comments.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/widgets/class-wp-widget-recent-posts.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/widgets/class-wp-widget-meta.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/certificates/ca-bundle.crt.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/IXR/class-IXR-server.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/IXR/class-IXR-client.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/IXR/class-IXR-error.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/IXR/class-IXR-request.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/IXR/class-IXR-date.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/IXR/class-IXR-base64.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/IXR/class-IXR-message.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/IXR/class-IXR-clientmulticall.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/IXR/class-IXR-introspectionserver.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/IXR/class-IXR-value.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/rest-api/class-wp-rest-request.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/rest-api/class-wp-rest-response.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/rest-api/fields/class-wp-rest-post-meta-fields.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/rest-api/fields/class-wp-rest-comment-meta-fields.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/rest-api/fields/class-wp-rest-term-meta-fields.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/rest-api/fields/class-wp-rest-user-meta-fields.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/rest-api/endpoints/class-wp-rest-controller.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/SimplePie/Enclosure.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/SimplePie/Rating.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/SimplePie/Restriction.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/SimplePie/Item.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/SimplePie/gzdecode.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/SimplePie/IRI.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/SimplePie/Author.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/SimplePie/Category.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-includes/SimplePie/Exception.php.cfg.json
# ...
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/farbtastic.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/l10n-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/farbtastic-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/customize-controls.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/edit-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/common.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/customize-nav-menus.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/press-this-editor.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/media.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/login-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/login.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/themes-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/edit-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/list-tables.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/deprecated-media-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/install-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/widgets-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/press-this.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/l10n.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/site-icon-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/admin-menu-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/edit.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/admin-menu-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/farbtastic.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/customize-widgets-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/forms-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/customize-nav-menus-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/revisions.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/revisions.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/press-this-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/deprecated-media.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/about-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/press-this-editor.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/press-this.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/widgets.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/color-picker-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/nav-menus.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/deprecated-media-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/list-tables-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/farbtastic-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/press-this-editor-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/install.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/install.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/customize-controls-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/login-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/list-tables.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/wp-admin.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/site-icon-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/themes.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/media.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/widgets-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/wp-admin-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/nav-menus.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/media-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/customize-widgets.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/install-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/widgets.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/ie-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/about.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/common-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/color-picker.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/login.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/about-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/common-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/wp-admin.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/about.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/ie.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/themes.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/press-this-editor-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/customize-nav-menus-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/customize-nav-menus.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/ie.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/wp-admin-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/revisions-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/revisions-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/forms.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/dashboard.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/nav-menus-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/dashboard.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/customize-controls-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/l10n.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/customize-controls.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/l10n-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/dashboard-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/customize-widgets-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/customize-widgets.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/press-this-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/color-picker-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/_mixins.scss.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/_admin.scss.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/_variables.scss.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/ectoplasm/colors.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/ectoplasm/colors.scss.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/ectoplasm/colors-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/ectoplasm/colors-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/ectoplasm/colors.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/sunrise/colors.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/sunrise/colors.scss.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/sunrise/colors-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/sunrise/colors-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/sunrise/colors.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/ocean/colors.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/ocean/colors.scss.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/ocean/colors-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/ocean/colors-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/ocean/colors.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/blue/colors.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/blue/colors.scss.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/blue/colors-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/blue/colors-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/blue/colors.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/coffee/colors.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/coffee/colors.scss.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/coffee/colors-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/coffee/colors-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/coffee/colors.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/midnight/colors.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/midnight/colors.scss.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/midnight/colors-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/midnight/colors-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/midnight/colors.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/light/colors.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/light/colors.scss.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/light/colors-rtl.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/light/colors-rtl.min.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/css/colors/light/colors.css.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/freedoms.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/users.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/site-info.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/update.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/theme-install.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/plugin-editor.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/plugin-install.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/admin.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/plugins.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/user-edit.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/profile.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/update-core.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/settings.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/about.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/site-settings.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/setup.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/theme-editor.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/site-themes.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/credits.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/user-new.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/sites.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/site-users.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/site-new.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/menu.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/edit.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/index.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/upgrade.php.cfg.json
# Visiting CFG from file ../part_2/wordpress/wordpress_ast_cfg/wp-admin/network/themes.php.cfg.json
